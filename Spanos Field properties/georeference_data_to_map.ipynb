# %%
import folium
import geopandas as gpd
import pandas as pd
import numpy as np

# %% [markdown]
# ### View satellite image of field

# %%
# Spanos field at Cal Poly SLO
location = [35.298387792355854, -120.66508935519974]

m = folium.Map(location=location, zoom_start=20, max_zoom=20)

folium.TileLayer(
    tiles="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}",
    attr="Esri",
    name="Esri Satellite",
    overlay=False,
    control=True,
    max_zoom=20,
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe5f6d3bd7a95e0bad491896b0cc1733 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe5f6d3bd7a95e0bad491896b0cc1733&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe5f6d3bd7a95e0bad491896b0cc1733 = L.map(
#                 &quot;map_fe5f6d3bd7a95e0bad491896b0cc1733&quot;,
#                 {
#                     center: [35.298387792355854, -120.66508935519974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c28fbf5626914c585408e7e63494fd92 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c28fbf5626914c585408e7e63494fd92.addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var tile_layer_5e970c641debf3f4a5baf8997367312b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5e970c641debf3f4a5baf8997367312b.addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var layer_control_6b06b424a8787257046ed2ae50397265_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c28fbf5626914c585408e7e63494fd92,
#                     &quot;Esri Satellite&quot; : tile_layer_5e970c641debf3f4a5baf8997367312b,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_6b06b424a8787257046ed2ae50397265 = L.control.layers(
#                 layer_control_6b06b424a8787257046ed2ae50397265_layers.base_layers,
#                 layer_control_6b06b424a8787257046ed2ae50397265_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Plot polygon of field outline

# %%
# grab 4 field corners on Google Earth
ne = [35.298971, -120.664876]
se = [35.298036, -120.664575]
sw = [35.297895, -120.665234]
nw = [35.298829, -120.665535]

# %%
folium.Marker(nw, icon=folium.Icon(icon="d", prefix="fa", color="black")).add_to(m)
folium.Marker(ne, icon=folium.Icon(icon="c", prefix="fa", color="black")).add_to(m)
folium.Marker(sw, icon=folium.Icon(icon="b", prefix="fa", color="black")).add_to(m)
folium.Marker(se, icon=folium.Icon(icon="a", prefix="fa", color="black")).add_to(m)

folium.Polygon(
    locations=[ne, se, sw, nw],
    color="blue",
    weight=2,
    fill=True,
    fill_color="blue",
    fill_opacity=0.2,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe5f6d3bd7a95e0bad491896b0cc1733 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe5f6d3bd7a95e0bad491896b0cc1733&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe5f6d3bd7a95e0bad491896b0cc1733 = L.map(
#                 &quot;map_fe5f6d3bd7a95e0bad491896b0cc1733&quot;,
#                 {
#                     center: [35.298387792355854, -120.66508935519974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c28fbf5626914c585408e7e63494fd92 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c28fbf5626914c585408e7e63494fd92.addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var tile_layer_5e970c641debf3f4a5baf8997367312b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5e970c641debf3f4a5baf8997367312b.addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var layer_control_6b06b424a8787257046ed2ae50397265_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c28fbf5626914c585408e7e63494fd92,
#                     &quot;Esri Satellite&quot; : tile_layer_5e970c641debf3f4a5baf8997367312b,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_6b06b424a8787257046ed2ae50397265 = L.control.layers(
#                 layer_control_6b06b424a8787257046ed2ae50397265_layers.base_layers,
#                 layer_control_6b06b424a8787257046ed2ae50397265_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#
#             tile_layer_c28fbf5626914c585408e7e63494fd92.addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             tile_layer_5e970c641debf3f4a5baf8997367312b.addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var marker_403a4ff6181c060788b9c0835b8d7234 = L.marker(
#                 [35.298829, -120.665535],
#                 {}
#             ).addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var icon_a81e1b48fac4431d9a13d3c845daafac = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;d&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_403a4ff6181c060788b9c0835b8d7234.setIcon(icon_a81e1b48fac4431d9a13d3c845daafac);
#
#
#             var marker_4f86cbc1838759566af20d05137b0516 = L.marker(
#                 [35.298971, -120.664876],
#                 {}
#             ).addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var icon_e8fbece018767224e670f4279b739bbf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;c&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4f86cbc1838759566af20d05137b0516.setIcon(icon_e8fbece018767224e670f4279b739bbf);
#
#
#             var marker_ed2609c95cd604e7e10a1f3e615b0b62 = L.marker(
#                 [35.297895, -120.665234],
#                 {}
#             ).addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var icon_00c477b6a27874f0eb29d080770ff036 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;b&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ed2609c95cd604e7e10a1f3e615b0b62.setIcon(icon_00c477b6a27874f0eb29d080770ff036);
#
#
#             var marker_f5a8c239176cb9bbcf81e449decc64b0 = L.marker(
#                 [35.298036, -120.664575],
#                 {}
#             ).addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var icon_c8f05b67afd086367acbb67484c665f2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;a&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f5a8c239176cb9bbcf81e449decc64b0.setIcon(ic

# %% [markdown]
# ### Generate data collection points

# %%
field_length_ft = 352
field_width_ft = 204

row_spacing_ft = 22
col_spacing_ft = 38

start_offset_x_ft = 3
start_offset_y_ft = 5

# %%
def interpolate_points(start, end, num_points):
    return [start + t * (end - start) for t in np.linspace(0, 1, num_points)]


# field edges
north_vector = np.array(ne) - np.array(nw)
south_vector = np.array(se) - np.array(sw)
west_vector = np.array(sw) - np.array(nw)

# offset from edge
x_fraction = start_offset_x_ft / field_width_ft
y_fraction = start_offset_y_ft / field_length_ft

# points for each column
start_point = np.array(nw) + y_fraction * north_vector + x_fraction * west_vector
num_points_per_row = 10
num_columns = 10
row_spacing_fraction = row_spacing_ft / field_width_ft
col_spacing_fraction = col_spacing_ft / field_length_ft

points_list = []

# start at 100 and count down, based on how we collected the data
point_id = 100
for col in range(num_columns):
    col_start_point = start_point + col * col_spacing_fraction * north_vector
    column_points = interpolate_points(
        col_start_point,
        col_start_point + row_spacing_fraction * west_vector * (num_points_per_row - 1),
        num_points_per_row,
    )
    for point in column_points:
        points_list.append(
            {"id": point_id, "latitude": point[0], "longitude": point[1]}
        )
        point_id -= 1

points_data = pd.DataFrame(points_list)
points_data.head()
# Out:
#     id   latitude   longitude
# 0  100  35.298817 -120.665521
# 1   99  35.298717 -120.665489
# 2   98  35.298616 -120.665456
# 3   97  35.298515 -120.665424
# 4   96  35.298414 -120.665391

# %%
for idx, row in points_data.iterrows():
    folium.CircleMarker(
        location=[row["latitude"], row["longitude"]],
        radius=5,
        color=None,
        fill=True,
        fill_color="red",
        fill_opacity=1,
        popup=f'Point {int(row["id"])}',
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe5f6d3bd7a95e0bad491896b0cc1733 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe5f6d3bd7a95e0bad491896b0cc1733&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe5f6d3bd7a95e0bad491896b0cc1733 = L.map(
#                 &quot;map_fe5f6d3bd7a95e0bad491896b0cc1733&quot;,
#                 {
#                     center: [35.298387792355854, -120.66508935519974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c28fbf5626914c585408e7e63494fd92 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c28fbf5626914c585408e7e63494fd92.addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var tile_layer_5e970c641debf3f4a5baf8997367312b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5e970c641debf3f4a5baf8997367312b.addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var layer_control_6b06b424a8787257046ed2ae50397265_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c28fbf5626914c585408e7e63494fd92,
#                     &quot;Esri Satellite&quot; : tile_layer_5e970c641debf3f4a5baf8997367312b,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_6b06b424a8787257046ed2ae50397265 = L.control.layers(
#                 layer_control_6b06b424a8787257046ed2ae50397265_layers.base_layers,
#                 layer_control_6b06b424a8787257046ed2ae50397265_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#
#             tile_layer_c28fbf5626914c585408e7e63494fd92.addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             tile_layer_5e970c641debf3f4a5baf8997367312b.addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var marker_403a4ff6181c060788b9c0835b8d7234 = L.marker(
#                 [35.298829, -120.665535],
#                 {}
#             ).addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var icon_a81e1b48fac4431d9a13d3c845daafac = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;d&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_403a4ff6181c060788b9c0835b8d7234.setIcon(icon_a81e1b48fac4431d9a13d3c845daafac);
#
#
#             var marker_4f86cbc1838759566af20d05137b0516 = L.marker(
#                 [35.298971, -120.664876],
#                 {}
#             ).addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var icon_e8fbece018767224e670f4279b739bbf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;c&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4f86cbc1838759566af20d05137b0516.setIcon(icon_e8fbece018767224e670f4279b739bbf);
#
#
#             var marker_ed2609c95cd604e7e10a1f3e615b0b62 = L.marker(
#                 [35.297895, -120.665234],
#                 {}
#             ).addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var icon_00c477b6a27874f0eb29d080770ff036 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;b&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ed2609c95cd604e7e10a1f3e615b0b62.setIcon(icon_00c477b6a27874f0eb29d080770ff036);
#
#
#             var marker_f5a8c239176cb9bbcf81e449decc64b0 = L.marker(
#                 [35.298036, -120.664575],
#                 {}
#             ).addTo(map_fe5f6d3bd7a95e0bad491896b0cc1733);
#
#
#             var icon_c8f05b67afd086367acbb67484c665f2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;a&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f5a8c239176cb9bbcf81e449decc64b0.setIcon(ic

# %% [markdown]
# ### Save csv of georeferenced points

# %%
points_data.to_csv("./points.csv", index=False)
